# %%
3+2
# Out:
# 5

# %%
from pyecharts import Pie
from pyecharts.engine import create_default_environment

from BillDetail import read_csv, get_payment_list, get_income_list, get_payment_list_detail

read_csv('jolin.csv')
total_payment = get_payment_list()
print("账单支出: %s" % str(total_payment))
total_income = get_income_list()
print("账单收入: %s" % str(total_income))
get_payment_list_detail()

attr = ["收入", "支出"]
v1 = [total_income, total_payment]
pie = Pie("饼图示例")
pie.add("", attr, v1, is_label_show=True)
pie.render("./pie.html")
# env = create_default_environment("html")
# env.render_chart_to_file(pie, path="./pie.html")
print("运行成功")
# Out:
# ERROR:lml.utils:failed to import pyecharts_snapshot
# Traceback (most recent call last):
#   File "f:\python3.6\lib\site-packages\lml\utils.py", line 43, in do_import
#     plugin_module = __import__(plugin_module_name)
# ModuleNotFoundError: No module named 'pyecharts_snapshot'
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 收入
# 收入
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 收入
# 收入
# 支出
# 支出
# 收入
# 支出
# 支出
# 支出
# 支出
# 支出
# 收入
# 收入
# 支出
# 收入
# 支出
# 支出
# 支出
# 收入
# 支出
# 收入
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# /
# 支出
# 支出
# 支出
# 收入
# 支出
# 支出
# 支出
# 收入
# 支出
# 支出
# 支出
# 支出
# 收入
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 收入
# 收入
# 支出
# 支出
# 支出
# 收入
# 支出
# 支出
# 支出
# 支出
# 收入
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 收入
# 支出
# 支出
# 收入
# 收入
# 收入
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 收入
# 支出
# 收入
# 支出
# 支出
# 账单支出: 4346.33
# 账单收入: 2052.84
# 支出最大值:1000.0,支付给:姜辉
# 运行成功

# %%
from pyecharts import Pie
import pyecharts_snapshot

from pyecharts.engine import create_default_environment

from BillDetail import read_csv, get_payment_list, get_income_list, get_payment_list_detail

read_csv('jolin.csv')
total_payment = get_payment_list()
print("账单支出: %s" % str(total_payment))
total_income = get_income_list()
print("账单收入: %s" % str(total_income))
get_payment_list_detail()

attr = ["收入", "支出"]
v1 = [total_income, total_payment]
pie = Pie("饼图示例")
pie.add("", attr, v1, is_label_show=True)
pie.render("./pie.html")
# env = create_default_environment("html")
# env.render_chart_to_file(pie, path="./pie.html")
print("运行成功")
# Out:
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 收入
# 收入
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 收入
# 收入
# 支出
# 支出
# 收入
# 支出
# 支出
# 支出
# 支出
# 支出
# 收入
# 收入
# 支出
# 收入
# 支出
# 支出
# 支出
# 收入
# 支出
# 收入
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# /
# 支出
# 支出
# 支出
# 收入
# 支出
# 支出
# 支出
# 收入
# 支出
# 支出
# 支出
# 支出
# 收入
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 收入
# 收入
# 支出
# 支出
# 支出
# 收入
# 支出
# 支出
# 支出
# 支出
# 收入
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 收入
# 支出
# 支出
# 收入
# 收入
# 收入
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 支出
# 收入
# 支出
# 收入
# 支出
# 支出
# 账单支出: 8692.66
# 账单收入: 4105.68
# 支出最大值:2000.0,支付给:姜辉
# 运行成功

# %%
from pyecharts import Pie

attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [11, 12, 13, 10, 10, 10]
pie = Pie("饼图示例")
pie.add("", attr, v1, is_label_show=True)
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="a2507c87322b4e39a0d2e5f893298758" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_a2507c87322b4e39a0d2e5f893298758 = echarts.init(document.getElementById('a2507c87322b4e39a0d2e5f893298758'), 'light', {renderer: 'canvas'});
#
# var option_a2507c87322b4e39a0d2e5f893298758 = {
#     "title": [
#         {
#             "text": "\u997c\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2910155,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u7f8a\u6bdb\u886b",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u96ea\u7eba\u886b",
#                     "value": 13
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 10
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 2910155
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_a2507c87322b4e39a0d2e5f893298758.setOption(option_a2507c87322b4e39a0d2e5f893298758);
#
#     });
# </script>
